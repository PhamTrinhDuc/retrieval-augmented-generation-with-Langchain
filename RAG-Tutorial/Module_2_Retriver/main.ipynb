# %% [markdown]
# ## **1. DOCUMENT LOADERS**

# %% [markdown]
# ### **1.1 Text File Loader**

# %%
from langchain.document_loaders import TextLoader

loader = TextLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/samle_text.txt")
documents = loader.load()
print(documents[0].page_content)
# Out:
# Thể loại tản mạn, tự sự:
# Depth of Feelings
# Đây là 1 blog mình cực kì yêu thích. Tác giả blog là chị Lê, bút danh Nguyên Kan. Chị Lê đang là Nghiên cứu sinh ngành Ngôn ngữ tại Pháp. Chị viết về nhiều chủ đề bao gồm sinh sống tại Pháp, nuôi dạy con (chị Lê có 2 cô bé rất dễ thương), cuộc sống hằng ngày, chụp ảnh, du lịch. Ai yêu thích chụp ảnh sẽ phải trầm trồ á ố vì các bức ảnh của chị Lê bởi chúng quá đẹp và có hồn. Xem blog và đọc blog của chị sẽ có cảm giác rất nhẹ nhàng, thơ mộng, thoải mái. Mình giới thiệu thêm là chị Lê còn là tác giả của cuốn sách “Mẹ đoảng dạy con” nữa.
# Go beyond our boundaries
# Đây là blog của chị Tôn Nữ Tường Vy. Mình biết chị Vy đã lâu, từ hồi tham gia chương trình Jenesys năm 2014. Chị Vy hơn mình vài tuổi nhưng rất giỏi, đi nhiều, hiểu rộng. Chị có rất nhiều chia sẻ sâu sắc trên blog này, từ việc du học đến những điều hay ho chị học được qua các chuyến đi. Chị cũng là tác giả của cuốn sách “Bên kia ranh giới”.
# Minhthi’s Blog
# ...

# %% [markdown]
# ### **1.2 CSV Loader**

# %%
from langchain.document_loaders import CSVLoader

loader = CSVLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/sample_csv.csv",
                   csv_args={
                       'delimiter': ',',
                        'quotechar': '"',
                        "fieldnames": ["name", "link", "tag"],
                   })


documents = loader.load()
print(documents[0].page_content)
print(documents[1].page_content)
print(documents[2].page_content)
# Out:
# name: name
# link: link
# tag: tag
# name: Bạn nên tránh sử dụng Soft Delete khi có thể, và đây là lý do tại sao
# link: https://viblo.asia/p/ban-nen-tranh-su-dung-soft-delete-khi-co-the-va-day-la-ly-do-tai-sao-LzD5dL1E5jY
# tag: rails
# name: Docker: Chưa biết gì đến biết dùng ( Phần 4 - Một số trick tối ưu và lưu ý )
# link: https://viblo.asia/p/docker-chua-biet-gi-den-biet-dung-phan-4-mot-so-trick-toi-uu-va-luu-y-LzD5dJREZjY
# tag: linux

# %% [markdown]
# ### **1.3 PDF Loader**

# %%
"""PyPDFLoader được sử dụng để phân tích cú pháp PDF cơ bản"""

from langchain.document_loaders import PyPDFLoader

loader = PyPDFLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/sample_pdf.pdf")
document = loader.load_and_split()
print(document[0].page_content)
# Out:
# I. Các loại sản phẩm
# 1. Bếp từ
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# 2. Lò vi sóng
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
# 3. Máy Giặt
# Số lượng sản phẩm là: 4
# - 571591: Máy giặt Electrolux UltimateCare 500 Inverter EWF1024P5SB
# - 571590: Máy giặt Electrolux UltimateCare 300 Inverter 10 kg EWF1024M3SB
# ...

# %%
# """MathPixLoader để trích xuất nội dung và công thức toán học."""

# from langchain.document_loaders import MathpixPDFLoader

# loader = MathpixPDFLoader("example_data/math-content.pdf")
# data = loader.load()

# %%
"""PyMuPDFLoader nhanh và bao gồm trích xuất siêu dữ liệu chi tiết."""


from langchain.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/sample_pdf.pdf")
document = loader.load(option="text")
print(document[0].page_content)
# Out:
# Received runtime arguments {'option': 'text'}. Passing runtime args to `load` is deprecated. Please pass arguments during initialization instead.
# I. Các loại sản phẩm
# 1. Bếp từ
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# 2. Lò vi sóng
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
# 3. Máy Giặt
# Số lượng sản phẩm là: 4
# ...

# %%
"""PDFMiner được sử dụng để kiểm soát chi tiết hơn việc trích xuất văn bản."""
from langchain.document_loaders import PDFMinerLoader

loader = PDFMinerLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/sample_pdf.pdf")
document = loader.load()

print(document[0].page_content)
# Out:
# I. Các loại sản phẩm
# 1. Bếp từ
#
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
#
# 2. Lò vi sóng
#
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
#
# 3. Máy Giặt
#
# Số lượng sản phẩm là: 4
# - 571591: Máy giặt Electrolux UltimateCare 500 Inverter EWF1024P5SB
# - 571590: Máy giặt Electrolux UltimateCare 300 Inverter 10 kg EWF1024M3SB
# ...

# %%
"""AmazonTextractPDFParser sử dụng AWS Textract cho OCR và các tính năng phân tích cú pháp PDF nâng cao khác."""

# from langchain.document_loaders import AmazonTextractPDFLoader

# loader = AmazonTextractPDFLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/sample_pdf.pdf")
# document = loader.load()
# print(document)
# Out:
# 'AmazonTextractPDFParser sử dụng AWS Textract cho OCR và các tính năng phân tích cú pháp PDF nâng cao khác.'

# %%
"""PDFPlumberLoader cung cấp siêu dữ liệu chi tiết và hỗ trợ một tài liệu trên mỗi trang."""

from langchain.document_loaders import PDFPlumberLoader

loader = PDFPlumberLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/sample_pdf.pdf")
document = loader.load()
print(document[0].page_content)
# Out:
# I. Các loại sản phẩm
# 1. Bếp từ
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# 2. Lò vi sóng
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
# 3. Máy Giặt
# Số lượng sản phẩm là: 4
# - 571591: Máy giặt Electrolux UltimateCare 500 Inverter EWF1024P5SB
# - 571590: Máy giặt Electrolux UltimateCare 300 Inverter 10 kg EWF1024M3SB
# ...

# %% [markdown]
# ### **1.4 Document Transformers**

# %%
"""Sử dụng RecursiveCharacterTextSplitter để split document đã load phía trên"""

from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=50,
    length_function=len,
    add_start_index=True,
)

text_recursive = text_splitter.split_documents(document)
print(text_recursive[0].page_content)
print("=" * 50)
print(text_recursive[1].page_content)
# Out:
# I. Các loại sản phẩm
# 1. Bếp từ
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# 2. Lò vi sóng
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
# 3. Máy Giặt
# Số lượng sản phẩm là: 4
# - 571591: Máy giặt Electrolux UltimateCare 500 Inverter EWF1024P5SB
# - 571590: Máy giặt Electrolux UltimateCare 300 Inverter 10 kg EWF1024M3SB
# ...

# %%
"""Sử dụng CharacterTextSplitter để split document đã load phía trên"""


from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    length_function=len,
    add_start_index=True,
)

text_chracter = text_splitter.split_documents(document)
print(text_chracter[0].page_content)
print("=" * 50)
print(text_chracter[1].page_content)
# Out:
# I. Các loại sản phẩm
# 1. Bếp từ
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# 2. Lò vi sóng
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
# 3. Máy Giặt
# Số lượng sản phẩm là: 4
# - 571591: Máy giặt Electrolux UltimateCare 500 Inverter EWF1024P5SB
# - 571590: Máy giặt Electrolux UltimateCare 300 Inverter 10 kg EWF1024M3SB
# ...

# %%
"""LangChain cung cấp các hàm chia cụ thể cho các ngôn ngữ lập trình khác nhau, như bộ chia mã Python và bộ chia mã JavaScript:"""

from langchain.text_splitter import RecursiveCharacterTextSplitter, Language

python_code = """
def hello_world():
    print("Hello, World!")
hello_world()
"""

python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, chunk_size=200
)
python_docs = python_splitter.create_documents([python_code])
print(python_docs[0])

js_code = """
function helloWorld() {
  console.log("Hello, World!");
}
helloWorld();
"""

js_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.JS, chunk_size=200
)
js_docs = js_splitter.create_documents([js_code])
print(js_docs[0])
# Out:
# page_content='def hello_world():\n    print("Hello, World!")\nhello_world()'
# page_content='function helloWorld() {\n  console.log("Hello, World!");\n}\nhelloWorld();'

# %% [markdown]
# # **2. TEXT EMBEDDING MODELS**

# %%
from langchain_community.embeddings.fastembed import FastEmbedEmbeddings


embedding_model = FastEmbedEmbeddings(model_name="BAAI/bge-small-en-v1.5")


embeddings = embedding_model.embed_documents(
    ["Xin chào",
     "Thành phố Hưng Yên đổi mới với nhiều phương pháp cải cách mới",
     "Hà Nội được đánh giá là thành phố có giá cả đăt đỏ nhât cả nước",
     "Việt Nam là đất nước được nhiều du khách nước ngoài yêu thích"]
)

print("Number of documents embedded:", len(embeddings))
print("Dimension of each embedding:", len(embeddings[0]))
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Number of documents embedded: 4
# Dimension of each embedding: 384

# %% [markdown]
# # **3. VECTOR STORES**

# %% [markdown]
# ## **3.1 Vector embedding with Chroma**

# %%
from langchain.vectorstores import Chroma

chroma = Chroma.from_documents(text_recursive, embedding_model)

similar_texts = chroma.similarity_search("Liệt kê các sản phẩm bếp từ")
print(similar_texts[0].page_content)

print("=" * 50)

print(similar_texts[1].page_content)
# Out:
# I. Các loại sản phẩm
# 1. Bếp từ
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# 2. Lò vi sóng
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
# 3. Máy Giặt
# Số lượng sản phẩm là: 4
# - 571591: Máy giặt Electrolux UltimateCare 500 Inverter EWF1024P5SB
# - 571590: Máy giặt Electrolux UltimateCare 300 Inverter 10 kg EWF1024M3SB
# ...

# %% [markdown]
# ## **3.2 Vector embedding with FAISS**

# %%
from langchain.vectorstores import FAISS

faiss = FAISS.from_documents(text_recursive, embedding_model)
similar_faiss = faiss.similarity_search("Số lượng các sản phẩm bếp từ")
print(similar_faiss[0].page_content)
# Out:
# I. Các loại sản phẩm
# 1. Bếp từ
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# 2. Lò vi sóng
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
# 3. Máy Giặt
# Số lượng sản phẩm là: 4
# - 571591: Máy giặt Electrolux UltimateCare 500 Inverter EWF1024P5SB
# - 571590: Máy giặt Electrolux UltimateCare 300 Inverter 10 kg EWF1024M3SB
# ...

# %%
print(similar_faiss[1].page_content)
# Out:
# - Tên sản phẩm: Máy Ép Chậm Bluestone Sjb-6568
# - Mô tả: Máy ép cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 30. Nồi chiên không dầu: 577839
# - Tên sản phẩm: Nôì chiên không dầu KALITE STEAM 7 7 lít
# - Mô tả: Nồi chiên hơi nước Kalite Steam 7 là sự kết hợp đột phá công nghệ chiên không
# dầu Rapid Air kết hợp hấp siêu nhiệt Steam Active, giúp bạn chế biến mọi món ăn dinh dưỡng hơn,
# thơm ngon hơn và tiết kiệm thời gian tối ưu.
# 31. Nồi chiên không dầu: 509226
# - Tên sản phẩm: Nồi chiên không dầu Philips công suất 1400 W, với công nghệ Rapid Air
# lành mạnh HD9200/90
# - Mô tả: Nồi chiên không dầu cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi
# AIOSMART
# 32. Nồi chiên không dầu: 577838
# - Tên sản phẩm: Nồi chiên không dầu KALITE Q5
# - Mô tả: Nồi chiên không dầu Kalite Q5 với công nghệ chiên không dầu Rapid Air giảm
# 95% chất béo, giúp bạn có những món ăn chiên nướng chín vàng đều, giòn rụm mà vẫn đảm bảo
# sức khoẻ.
# 33. Nồi chiên không dầu: 509231

# %%
print(similar_faiss[2].page_content)
# Out:
# 6. Bếp từ: 509336
# - Tên sản phẩm: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - Mô tả: Bếp từ cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 7. Bếp từ: 509337
# - Tên sản phẩm: Bếp Từ Đôi Bluestone Icb-6948
# - Mô tả: Bếp từ cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 8. Bếp từ: 509335
# - Tên sản phẩm: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - Mô tả: Bếp từ cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 9. Bếp từ: 509334
# - Tên sản phẩm: Bếp Từ Đôi Bluestone Icb-6845
# - Mô tả: Bếp từ cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 10. Bếp từ: 509329
# - Tên sản phẩm: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# - Mô tả: Bếp từ cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 11. Lò vi sóng: 509347
# - Tên sản phẩm: Lò Vi Sóng Bluestone Mob-7733
# - Mô tả: Lò vi sóng cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 12. Lò vi sóng: 509348
# - Tên sản phẩm: Lò Vi Sóng Bluestone Mob-7833

# %% [markdown]
# ## **3.3 Vector embedding with QDrant**

# %% [markdown]
# #### 3.3.1 Search similarity

# %%
from langchain.vectorstores import Qdrant

qdrant = Qdrant.from_documents(
    text_recursive,
    embedding_model,
    location=":memory:",  # Local mode with in-memory storage only
)
similar_qdrant = qdrant.similarity_search("có bao nhiêu sản phẩm bếp từ ?")
print(similar_qdrant[0].page_content)
# Out:
# - Tên sản phẩm: Máy Ép Chậm Bluestone Sjb-6568
# - Mô tả: Máy ép cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 30. Nồi chiên không dầu: 577839
# - Tên sản phẩm: Nôì chiên không dầu KALITE STEAM 7 7 lít
# - Mô tả: Nồi chiên hơi nước Kalite Steam 7 là sự kết hợp đột phá công nghệ chiên không
# dầu Rapid Air kết hợp hấp siêu nhiệt Steam Active, giúp bạn chế biến mọi món ăn dinh dưỡng hơn,
# thơm ngon hơn và tiết kiệm thời gian tối ưu.
# 31. Nồi chiên không dầu: 509226
# - Tên sản phẩm: Nồi chiên không dầu Philips công suất 1400 W, với công nghệ Rapid Air
# lành mạnh HD9200/90
# - Mô tả: Nồi chiên không dầu cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi
# AIOSMART
# 32. Nồi chiên không dầu: 577838
# - Tên sản phẩm: Nồi chiên không dầu KALITE Q5
# - Mô tả: Nồi chiên không dầu Kalite Q5 với công nghệ chiên không dầu Rapid Air giảm
# 95% chất béo, giúp bạn có những món ăn chiên nướng chín vàng đều, giòn rụm mà vẫn đảm bảo
# sức khoẻ.
# 33. Nồi chiên không dầu: 509231

# %% [markdown]
# ##### 3.3.2 Search similarity search with score

# %%
from langchain.vectorstores import Qdrant

"""Similarity search with score"""

qdrant = Qdrant.from_documents(
    text_recursive,
    embedding_model,
    location=":memory:",  # Local mode with in-memory storage only
)
similar_qdrant = qdrant.similarity_search_with_score("có bao nhiêu sản phẩm bếp từ ?")
print("Query similar: \n", similar_qdrant[0][0].page_content)
print("Score: \n", similar_qdrant[0][1])
# Out:
# Query similar:
#  - Tên sản phẩm: Máy Ép Chậm Bluestone Sjb-6568
# - Mô tả: Máy ép cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 30. Nồi chiên không dầu: 577839
# - Tên sản phẩm: Nôì chiên không dầu KALITE STEAM 7 7 lít
# - Mô tả: Nồi chiên hơi nước Kalite Steam 7 là sự kết hợp đột phá công nghệ chiên không
# dầu Rapid Air kết hợp hấp siêu nhiệt Steam Active, giúp bạn chế biến mọi món ăn dinh dưỡng hơn,
# thơm ngon hơn và tiết kiệm thời gian tối ưu.
# 31. Nồi chiên không dầu: 509226
# - Tên sản phẩm: Nồi chiên không dầu Philips công suất 1400 W, với công nghệ Rapid Air
# lành mạnh HD9200/90
# - Mô tả: Nồi chiên không dầu cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi
# AIOSMART
# 32. Nồi chiên không dầu: 577838
# - Tên sản phẩm: Nồi chiên không dầu KALITE Q5
# - Mô tả: Nồi chiên không dầu Kalite Q5 với công nghệ chiên không dầu Rapid Air giảm
# 95% chất béo, giúp bạn có những món ăn chiên nướng chín vàng đều, giòn rụm mà vẫn đảm bảo
# sức khoẻ.
# ...

# %%
print("Query similar: \n", similar_qdrant[1][0].page_content)
print("Score: \n", similar_qdrant[1][1])
# Out:
# Query similar:
#  I. Các loại sản phẩm
# 1. Bếp từ
# Số lượng sản phẩm là: 10
# - 606015: Bộ nồi Inox sơn đỏ (3 cái/Bộ)-AIO Smart
# - 509333: Bếp Từ Bluestone Icb-6619
# - 509331: Bếp Từ Bluestone Icb-6609
# - 509330: Bếp Từ Đôi Bluestone Icb-6833
# - 509328: Bếp Từ Đôi Bluestone Icb-6818
# - 509336: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6917
# - 509337: Bếp Từ Đôi Bluestone Icb-6948
# - 509335: Bếp Hỗn Hợp Quang Từ Bluestone Icb-6911
# - 509334: Bếp Từ Đôi Bluestone Icb-6845
# - 509329: Bếp Hỗn Hợp Quang Từ Bluestone Icb- 6821
# 2. Lò vi sóng
# Số lượng sản phẩm là: 5
# - 509347: Lò Vi Sóng Bluestone Mob-7733
# - 509348: Lò Vi Sóng Bluestone Mob-7833
# - 509344: Lò Vi Sóng Bluestone Mob-7708B
# - 509345: Lò Vi Sóng Bluestone MOB-7716 có nướng 20 lít
# - 509346: Lò Vi Sóng Bluestone Mob-7816
# 3. Máy Giặt
# Số lượng sản phẩm là: 4
# - 571591: Máy giặt Electrolux UltimateCare 500 Inverter EWF1024P5SB
# - 571590: Máy giặt Electrolux UltimateCare 300 Inverter 10 kg EWF1024M3SB
# ...

# %% [markdown]
# #### 3.3.3 Maximum marginal relevance search (MMR)

# %%
query = "Liệt kê các sản phẩm điều hòa"

found_docs = qdrant.max_marginal_relevance_search(query, k=2, fetch_k=10)

for i, doc in enumerate(found_docs):
    print(f"{i + 1}.", doc.page_content, "\n")
# Out:
# 1. - Mô tả: Điều hòa cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 66. Điều hòa: 509382
# - Tên sản phẩm: Điều hòa treo tường Aqua AQA-RV24QA
#
# 2. khác, đèn 100W chống loá được trang bị một choá đặc biệt để khi người sử dụng nhìn vào đèn sẽ
# không bị loá mắt, đau mắt.
# 91. Đèn Năng Lượng Mặt Trời: 577803
# - Tên sản phẩm: Bộ đèn đường năng lượng mặt trời Suntek, Model: S150

# %% [markdown]
# # **4. RETRIEVERS**

# %% [markdown]
# ### **4.1 Simple Retriever**

# %%
"""Retriever từ vector db của faiss đã được tạo bên trên"""

retriever = faiss.as_retriever()

query = "sản phảm nồi cơm điện 509172"
retrieved_docs = retriever.invoke(query)
print(retrieved_docs[0].page_content)
# Out:
# - Tên sản phẩm: Nồi Cơm Điện Bluestone Rcb-5512
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 57. Nồi cơm điện: 509316
# - Tên sản phẩm: Nồi Cơm Điện Bluestone Rcb-5538
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 58. Nồi cơm điện: 509318
# - Tên sản phẩm: Nồi Cơm Điện Tử
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 59. Nồi cơm điện: 509224
# - Tên sản phẩm: Nồi cơm điện Philips dung tích 1,8 lít công suất 790-940 W với 18 chương
# trình dê dàng thiết lập giúp bạn đổi mới công thức nấu ăn hàng ngày vô cùng đa dạng. HD4518/62
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 60. Nồi cơm điện: 509173
# - Tên sản phẩm: Nồi cơm điện KALITE KL-619, dung tích 1,8 lít
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 61. Nồi cơm điện: 509174
# - Tên sản phẩm: Nồi cơm điện tử KALITE KL-620, dung tích 1,8 lít

# %% [markdown]
# ### **4.2 MultiQueryRetriever**

# %%
from langchain_groq import ChatGroq
from langchain.retrievers.multi_query import MultiQueryRetriever
import os


"""Sử dụng MultiQueryRetriever để truy vấn"""

query = "Liệt kê sản phảm nồi cơm điện"

llm = ChatGroq(model="llama3-70b-8192", 
                api_key=os.getenv("GROQ_API_KEY"),
                temperature=0.1)


retriever_from_llm = MultiQueryRetriever.from_llm(
    retriever=faiss.as_retriever(), llm=llm
)
unique_docs = retriever_from_llm.get_relevant_documents(query=query)
print("Number of unique documents:", len(unique_docs))
print(unique_docs[0].page_content)
# Out:
# /home/ducpham/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# Number of unique documents: 15
# 28. Máy ép: 509253
# - Tên sản phẩm: Máy vắt nước cam Philips, công suất 25W, ca chứa nước ép 0.5 lít, lưới lọc
# tép cam, dây điện có thể quấn gọn HR2738/00
# - Mô tả: Máy ép cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 29. Máy ép: 509362

# %% [markdown]
# ### **4.3 Contextual Compression**

# %%
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor

"""Sử dụng Contextual Compression để truy vấn"""


llm = ChatGroq(model="llama3-70b-8192", 
                api_key=os.getenv("GROQ_API_KEY"),
                temperature=0.1)

compressor = LLMChainExtractor.from_llm(llm)
compression_retriever = ContextualCompressionRetriever(base_compressor=compressor, base_retriever=retriever)

compressed_docs = compression_retriever.get_relevant_documents(query)
print(compressed_docs[0].page_content)
# Out:
# Here are the extracted relevant parts of the context:
#
# - Tên sản phẩm: Nồi Cơm Điện Bluestone Rcb-5512
# - Tên sản phẩm: Nồi Cơm Điện Bluestone Rcb-5538
# - Tên sản phẩm: Nồi Cơm Điện Tử
# - Tên sản phẩm: Nồi cơm điện Philips dung tích 1,8 lít công suất 790-940 W với 18 chương trình dê dàng thiết lập giúp bạn đổi mới công thức nấu ăn hàng ngày vô cùng đa dạng. HD4518/62
# - Tên sản phẩm: Nồi cơm điện KALITE KL-619, dung tích 1,8 lít
# - Tên sản phẩm: Nồi cơm điện tử KALITE KL-620, dung tích 1,8 lít

# %% [markdown]
# ### **4.4 EnsembleRetriever**
# kết hợp các thuật toán truy xuất khác nhau để đạt được hiệu suất tốt hơn. Một ví dụ về việc kết hợp BM25 và FAISS Retrievers

# %%
from langchain.retrievers import BM25Retriever, EnsembleRetriever

bm25_retriever = BM25Retriever.from_documents(text_recursive)
faiss_retriever = faiss.as_retriever(search_kwargs={"k": 2})

ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, faiss_retriever],
    weights=[0.4, 0.6]
)

query = "Liệt kê sản phảm nồi cơm điện 509172"
docs = ensemble_retriever.get_relevant_documents(query)
print(docs[0].page_content)
# Out:
# - Tên sản phẩm: Nồi Cơm Điện Bluestone Rcb-5512
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 57. Nồi cơm điện: 509316
# - Tên sản phẩm: Nồi Cơm Điện Bluestone Rcb-5538
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 58. Nồi cơm điện: 509318
# - Tên sản phẩm: Nồi Cơm Điện Tử
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 59. Nồi cơm điện: 509224
# - Tên sản phẩm: Nồi cơm điện Philips dung tích 1,8 lít công suất 790-940 W với 18 chương
# trình dê dàng thiết lập giúp bạn đổi mới công thức nấu ăn hàng ngày vô cùng đa dạng. HD4518/62
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 60. Nồi cơm điện: 509173
# - Tên sản phẩm: Nồi cơm điện KALITE KL-619, dung tích 1,8 lít
# - Mô tả: Nồi cơm điện cao cấp, hàng chính hãng. Bảo hành toàn quốc bởi AIOSMART
# 61. Nồi cơm điện: 509174
# - Tên sản phẩm: Nồi cơm điện tử KALITE KL-620, dung tích 1,8 lít

# %% [markdown]
# ### **4.5 MultiVector Retriever**
# cho phép truy vấn các tài liệu có nhiều vectơ trên mỗi tài liệu, rất hữu ích để nắm bắt các khía cạnh ngữ nghĩa khác nhau trong tài liệu. Các phương pháp tạo nhiều vectơ bao gồm chia thành các phần nhỏ hơn, tóm tắt hoặc tạo các câu hỏi giả định.

# %%
from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.storage import  InMemoryStore
from langchain.document_loaders import TextLoader, CSVLoader
import uuid

# Load 2 file text and csv
loaders = [TextLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/samle_text.txt"), 
          CSVLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/sample_csv.csv")]
docs = [doc for loader in loaders for doc in loader.load()]

# Init splitter
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
# split document
docs = splitter.split_documents(docs)

# Init vector store uding Chroma db
vector_store = Chroma(embedding_function=embedding_model)
store = InMemoryStore()
id_key = "doc_id"

# Init retriever
retriever = MultiVectorRetriever(vectorstore=vector_store, 
                                docstore=store)
doc_ids = [str(uuid.uuid4()) for _ in docs]
child_text_splitter = RecursiveCharacterTextSplitter(chunk_size=400)
sub_docs = [sub_doc for doc in docs for sub_doc in child_text_splitter.split_documents([doc])]
# for sub_doc in sub_docs:
#     sub_doc.metadata[id_key] = doc_ids[sub_docs.index(sub_doc)]

retriever.vectorstore.add_documents(sub_docs)
retriever.docstore.mset(list(zip(doc_ids, docs)))
# Out:
# Exception occurred invoking consumer for subscription 65b4b53776844d1295edd2304074a706to topic persistent://default/default/d6565ea3-12af-4e14-94ec-5a8eac26e18a

# %% [markdown]
# ### **4.6 Parent Document Retriever**
# một công cụ truy xuất khác tạo ra sự cân bằng giữa độ chính xác khi embedding và khả năng lưu giữ ngữ cảnh bằng cách lưu trữ các đoạn nhỏ và truy xuất các tài liệu gốc lớn hơn của chúng.

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.document_loaders import TextLoader, CSVLoader


# Load 2 file text and csv
loaders = [TextLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/samle_text.txt"), 
          CSVLoader("/home/ducpham/Documents/VSC_PYTHON/RAG-Tutorial/Module_2_Retrival/data/sample_csv.csv")]
docs = [doc for loader in loaders for doc in loader.load()]

# Init splitter
child_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)

# Init vector store uding Chroma db
vector_store = Chroma(embedding_function=embedding_model)
store = InMemoryStore()

# Init retriever
retriever = ParentDocumentRetriever(vectorstore=vector_store, docstore=store, child_splitter=child_splitter)
retriever.add_documents(docs, ids=None)

retrieved_doc_1 = retriever.aget_relevant_documents("Có những thẻ loại tản mạn, tự sự nào ?")
# retrieved_doc_2 = retriever.aget_relevant_documents("Microservices là gì?")
print(retrieved_doc_1)
# print(retrieved_doc_2)
# Out:
# <coroutine object BaseRetriever.aget_relevant_documents at 0x785d84800040>
# /tmp/ipykernel_10832/3080076438.py:21: RuntimeWarning: coroutine 'BaseRetriever.aget_relevant_documents' was never awaited
#   retrieved_doc_1 = retriever.aget_relevant_documents("Có những thẻ loại tản mạn, tự sự nào ?")
# ...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
